# %%
#import하기
import pandas as pd

# %%
#데이터 준비하기 
train_data = pd.read_csv("E:\데이콘\\전복나이 예측\\데이터\\train.csv")

train_max_input = train_data.drop(['id', 'Target'], axis=1)
train_max_target = train_data['Target'].to_numpy()
train_max_input = pd.get_dummies(train_max_input).to_numpy()
ques_data = pd.read_csv("E:\데이콘\\전복나이 예측\\데이터\\test.csv")
ques_input = ques_data.drop(['id'], axis=1)
ques_input = pd.get_dummies(ques_input).to_numpy()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(train_max_input)
#print(train_max_input)
train_max_pca =pca.transform(train_max_input)
#print(train_max_pca)
ques_pca =pca.transform(ques_input)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
x = train_max_pca[:,0]
y = train_max_pca[:,1]
z = train_max_target
ax.scatter(x, y, z)
plt.show()
# Out:
# C:\Users\dlehd\AppData\Local\Temp\ipykernel_11104\571768404.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
import numpy as np

x = train_max_pca[:,0]
y = train_max_pca[:,1]
z = train_max_target
ax.scatter(x, y, z)
plt.show()
